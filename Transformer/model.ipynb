# %%
# !python -m pip install torch torchvision --index-url https://download.pytorch.org/whl/cu128

# %%
import torch
import torch.nn as nn
pe = torch.arange(0,2)
print(pe.shape)
print(pe.unsqueeze(0).shape)
print(pe.unsqueeze(1).shape)
# Out:
# torch.Size([2])
# torch.Size([1, 2])
# torch.Size([2, 1])

# %%
import torch
import torch.nn as nn

class InputEmbedding(nn.Module):
    def __init__(self, d_model:int, vocab_size:int):
        super().__init__() 
        self.d_model = d_model
        self.vocab_size = vocab_size
        self.embedding = nn.Embedding(vocab_size,d_model)
        
embedding = InputEmbedding(512,1000)
embedding.embedding.weight
# Out:
# Parameter containing:
# tensor([[-1.2300,  0.7311,  1.0274,  ...,  0.7858,  0.8069,  1.5224],
#         [ 0.6401,  0.1111, -1.7187,  ..., -0.0465, -0.7431, -0.3939],
#         [-1.6287,  0.7687, -0.3296,  ..., -1.5336, -1.1939, -0.0162],
#         ...,
#         [ 0.1061, -0.6229, -1.7259,  ..., -1.4282,  1.6792,  1.0267],
#         [ 0.0610,  0.3642,  0.1518,  ...,  1.2234,  1.4305, -2.0654],
#         [-0.4694, -1.0088,  0.3684,  ..., -0.1477,  0.1032,  1.0512]],
#        requires_grad=True)
